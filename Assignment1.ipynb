# %% [markdown]
# <a href="https://colab.research.google.com/github/sbanty/Scipy-computing/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Load the data

from google.colab import files
cnt_auction_df = files.upload()
# Out:
#      <input type="file" id="files-bde13d3f-333b-4d7e-bc2e-ef63370730fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bde13d3f-333b-4d7e-bc2e-ef63370730fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
type(cnt_auction_df)
cnt_auction_df = pd.read_csv('carbon_nanotubes.csv')

# %%
cnt = pd.DataFrame.from_dict(cnt_auction_df,orient = 'columns')
#cnt = pd.DataFrame.from_dict(ipl_auction_df, 10)
print(cnt)
type(cnt)
# Out:
#                                                      Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'
# 2;1;0  679005;0 701318;0 017033;0 721039;0 730232;0                                            17014.0
#        717298;0 642129;0 231319;0 738414;0 65675;0                                            232369.0
#        489336;0 303751;0 088462;0 477676;0 263221;0                                            88712.0
#        413957;0 632996;0 040843;0 408823;0 657897;0                                            39796.0
#        334292;0 543401;0 15989;0  303349;0 558807;0                                           157373.0
# ...                                                                                                ...
# ...

# %%
pd.set_option('display.max_columns',15)
cnt_auction_df.head(6)
# Out:
#                                                     Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'
# 2;1;0 679005;0 701318;0 017033;0 721039;0 730232;0                                            17014.0
#       717298;0 642129;0 231319;0 738414;0 65675;0                                            232369.0
#       489336;0 303751;0 088462;0 477676;0 263221;0                                            88712.0
#       413957;0 632996;0 040843;0 408823;0 657897;0                                            39796.0
#       334292;0 543401;0 15989;0  303349;0 558807;0                                           157373.0
#       510664;0 696249;0 255128;0 496977;0 725608;0                                            25597.0

# %%
list(cnt_auction_df.columns)
# Out:
# ["Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'"]

# %%
print(list(cnt.columns))
list(cnt.columns)
cnt.columns
# Out:
# ["Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'"]
# Index(['Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w''], dtype='object')

# %%
cnt_auction_df.head(5).transpose()
# Out:
#                                                       2;1;0            \
#                                                    679005;0  717298;0
#                                                    701318;0  642129;0
#                                                    017033;0  231319;0
#                                                    721039;0  738414;0
#                                                    730232;0   65675;0
# Chiral indice n;Chiral indice m;Initial atomic ...  17014.0  232369.0
#
#
#                                                    489336;0 413957;0  334292;0
#                                                    303751;0 632996;0  543401;0
#                                                    088462;0 040843;0   15989;0
#                                                    477676;0 408823;0  303349;0
#                                                    263221;0 657897;0  558807;0
# Chiral indice n;Chiral indice m;Initial atomic ...  88712.0  39796.0  157373.0

# %%
cnt_auction_df.shape
cnt_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10721 entries, ('2;1;0', '679005;0', '701318;0', '017033;0', '721039;0', '730232;0') to ('12;6;0', '953664;0', '698374;0', '962699;0', '961243;0', '707812;0')
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                  --------------  -----
#  0   Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'  10700 non-null  float64
# ...

# %%
cnt_auction_df[0:6]
# Out:
#                                                     Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'
# 2;1;0 679005;0 701318;0 017033;0 721039;0 730232;0                                            17014.0
#       717298;0 642129;0 231319;0 738414;0 65675;0                                            232369.0
#       489336;0 303751;0 088462;0 477676;0 263221;0                                            88712.0
#       413957;0 632996;0 040843;0 408823;0 657897;0                                            39796.0
#       334292;0 543401;0 15989;0  303349;0 558807;0                                           157373.0
#       510664;0 696249;0 255128;0 496977;0 725608;0                                            25597.0

# %%
cnt_auction_df[-6:]
# Out:
#                                                      Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w'
# 12;6;0 876454;0 467139;0 796032;0 882181;0 473901;0                                           796005.0
#        834201;0 399891;0 89127;0  841858;0 405882;0                                           891356.0
#        698374;0 24471;0  962699;0 706555;0 248416;0                                           962833.0
#        923823;0 568913;0 819842;0 929403;0 576284;0                                           819879.0
#        934978;0 602319;0 938889;0 941844;0 610608;0                                           938755.0
#        953664;0 698374;0 962699;0 961243;0 707812;0                                           962605.0

# %%
cnt_auction_df['TDNsa3VOcsBG'][0:5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TDNsa3VOcsBG'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1093712487.py in <cell line: 0>()
# ----> 1 cnt_auction_df['TDNsa3VOcsBG'][0:5]
#
# ...

# %%
print(cnt_auction_df.columns)
# Out:
# Index(['Chiral indice n;Chiral indice m;Initial atomic coordinate u;Initial atomic coordinate v;Initial atomic coordinate w;Calculated atomic coordinates u';Calculated atomic coordinates v';Calculated atomic coordinates w''], dtype='object')
